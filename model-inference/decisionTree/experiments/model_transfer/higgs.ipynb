# %%
import pandas
import pickle
import joblib
from sklearn.ensemble import RandomForestClassifier

filename = 'models/higgs/rf-10-8-6.pkl'
loaded_model = joblib.load(filename)

from sklearn.tree import export_graphviz
from IPython.display import Image
import pydotplus
import graphviz
import os

Estimators = loaded_model.estimators_
for index, model in enumerate(Estimators):
    filename = 'graphs/higgs/higgs_' + str(index) + '.pdf'
    outfilename = 'graphs/higgs/higgs_' + str(index) + '.txt'
    dot_data = export_graphviz(model)
    f = open(outfilename, 'w') 
    f.write(dot_data) 
    f.close()
    graph = pydotplus.graph_from_dot_data(dot_data)
    #Image(graph.create_png())
    #graph.write_pdf(filename)
    os.system('dot -Tpdf ' + outfilename + ' -o ' + filename)

# %%
import pandas as pd
import pickle
import joblib

df = pd.read_csv('datasets/higgs/HIGGS.csv')
df.head()
# Out:
#    1.000000000000000000e+00  8.692932128906250000e-01  \
# 0                       1.0                  0.907542
# 1                       1.0                  0.798835
# 2                       0.0                  1.344385
# 3                       1.0                  1.105009
# 4                       0.0                  1.595839
#
#    -6.350818276405334473e-01  2.256902605295181274e-01  \
# 0                   0.329147                  0.359412
# 1                   1.470639                 -1.635975
# 2                  -0.876626                  0.935913
# 3                   0.321356                  1.522401
# 4                  -0.607811                  0.007075
#
#    3.274700641632080078e-01  -6.899932026863098145e-01  \
# 0                  1.497970                  -0.313010
# 1                  0.453773                   0.425629
# 2                  1.992050                   0.882454
# 3                  0.882808                  -1.205349
# ...

# %%
print ("row,column")
print (df.shape[0],df.shape[1])
# Out:
# row,column
# 10999999 29
